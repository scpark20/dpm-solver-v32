# %%
import os
import numpy as np
import matplotlib.pyplot as plt

for scale in [2.0]: 
    print('scale :', scale)   
    for NFE in [5, 6, 8, 10, 12, 15, 20, 25]:
        for order in [4]:
            print(scale, NFE, order)
            root_dir = f'/data/guided-diffusion/scale/rbf_ecp_marginal{scale}'
            optimal_log_scales_list = []
            plt.figure(figsize=[3, 2])
            plt.title(f"NFE={NFE}, order={order}")
            for number in range(100):
                npz_file = os.path.join(root_dir, f'NFE={NFE},p={order},number={number}.npz')
                if not os.path.exists(npz_file):
                    continue
                data = np.load(npz_file)
                plt.plot(data['optimal_log_scales'].T, color='black', alpha=0.2)
                optimal_log_scales_list.append(data['optimal_log_scales'])
            optimal_log_scales = np.stack(optimal_log_scales_list, axis=0)
            print(len(optimal_log_scales))
            optimal_log_scales = np.mean(optimal_log_scales, axis=0)
            save_file = os.path.join(root_dir, f'NFE={NFE},p={order}.npz')
            np.savez(save_file, optimal_log_scales=optimal_log_scales)
            data = np.load(save_file)
            plt.plot(data['optimal_log_scales'].T, color='blue')
            plt.grid()
            plt.show()
# Out:
# scale : 2.0
# 2.0 5 4
# 20
# 2.0 6 4
# 20
# 2.0 8 4
# 20
# 2.0 10 4
# 20
# 2.0 12 4
# 20
# 2.0 15 4
# 20
# 2.0 20 4
# 20
# 2.0 25 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 21
#      19     plt.plot(data['optimal_log_scales'].T, color='black', alpha=0.2)
#      20     optimal_log_scales_list.append(data['optimal_log_scales'])
# ---> 21 optimal_log_scales = np.stack(optimal_log_scales_list, axis=0)
#      22 print(len(optimal_log_scales))
#      23 optimal_log_scales = np.mean(optimal_log_scales, axis=0)
#
# File <__array_function__ internals>:180, in stack(*args, **kwargs)
#
# File ~/miniconda3/envs/rbf/lib/python3.11/site-packages/numpy/core/shape_base.py:422, in stack(arrays, axis, out)
#     420 arrays = [asanyarray(arr) for arr in arrays]
#     421 if not arrays:
# --> 422     raise ValueError('need at least one array to stack')
#     424 shapes = {arr.shape for arr in arrays}
#     425 if len(shapes) != 1:
#
# ValueError: need at least one array to stack
