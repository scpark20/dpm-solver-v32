# %%
import os
os.chdir('../')

# %%
# !ls samples/imagenet64_uncond_100M_1500K/unipc_200_scale/images
# Out:
# samples_0.npz  samples_2.npz  samples_4.npz  samples_6.npz
# samples_1.npz  samples_3.npz  samples_5.npz  samples_7.npz

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.load('samples/imagenet64_uncond_100M_1500K/unipc_200_scale/images/samples_0.npz')
image = data['datas_raw'].transpose(0, 2, 3, 1)
plt.imshow(image[5])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-407.5764..263.70102].

# %%
image.max()
# Out:
# 488.445
