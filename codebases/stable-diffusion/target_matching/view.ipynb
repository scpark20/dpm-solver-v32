# %%
import numpy as np
import matplotlib.pyplot as plt

SCALE = 3.5

for ORDER in [2, 3]:
    for NFE in [5, 6, 8, 10, 12, 15, 20]:
        plt.figure(figsize=[5, 3])
        plt.title(f'Order={ORDER}, NFE={NFE}')
        optimal_log_scales_list = []
        for number in range(20):
            np_data = np.load(f'/data/ldm/scale{SCALE}/NFE={NFE},p={ORDER},number={number}.npz')
            optimal_log_scales_list.append(np_data['optimal_log_scales'])
            plt.plot(np_data['optimal_log_scales'].T, color='black', alpha=0.1)

        np_data = np.load(f'/data/ldm/scale{SCALE}/NFE={NFE},p={ORDER}.npz')
        plt.plot(np_data['optimal_log_scales'].T, color='blue', alpha=1)
        plt.grid()
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 optimal_log_scales_list = []
#      11 for number in range(20):
# ---> 12     np_data = np.load(f'/data/ldm/scale{SCALE}/NFE={NFE},p={ORDER},number={number}.npz')
#      13     optimal_log_scales_list.append(np_data['optimal_log_scales'])
#      14     plt.plot(np_data['optimal_log_scales'].T, color='black', alpha=0.1)
#
# File ~/miniconda3/envs/rbf/lib/python3.11/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/ldm/scale3.5/NFE=15,p=2,number=9.npz'
