# %%
# !ls /data/ldm/scale_traj7.5/
# Out:
# 'NFE=5,p=2.npz'		   'NFE=5,p=2,number=6.npz'   'NFE=6,p=2,number=2.npz'
# 'NFE=5,p=2,number=0.npz'   'NFE=5,p=2,number=7.npz'   'NFE=6,p=2,number=3.npz'
# 'NFE=5,p=2,number=10.npz'  'NFE=5,p=2,number=8.npz'   'NFE=6,p=2,number=4.npz'
# 'NFE=5,p=2,number=11.npz'  'NFE=5,p=2,number=9.npz'   'NFE=6,p=2,number=5.npz'
# 'NFE=5,p=2,number=12.npz'  'NFE=6,p=2.npz'	      'NFE=6,p=2,number=6.npz'
# 'NFE=5,p=2,number=13.npz'  'NFE=6,p=2,number=0.npz'   'NFE=6,p=2,number=7.npz'
# 'NFE=5,p=2,number=14.npz'  'NFE=6,p=2,number=10.npz'  'NFE=6,p=2,number=8.npz'
# 'NFE=5,p=2,number=15.npz'  'NFE=6,p=2,number=11.npz'  'NFE=6,p=2,number=9.npz'
# 'NFE=5,p=2,number=16.npz'  'NFE=6,p=2,number=12.npz'  'NFE=8,p=2,number=0.npz'
# 'NFE=5,p=2,number=17.npz'  'NFE=6,p=2,number=13.npz'  'NFE=8,p=2,number=1.npz'
# 'NFE=5,p=2,number=18.npz'  'NFE=6,p=2,number=14.npz'  'NFE=8,p=2,number=2.npz'
# 'NFE=5,p=2,number=19.npz'  'NFE=6,p=2,number=15.npz'  'NFE=8,p=2,number=3.npz'
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def show_scale(npz_file):
    data = np.load(npz_file)
    log_scales = data['optimal_log_scales']
    plt.plot(log_scales.T)
    plt.show()

#show_scale('/data/ldm/scale7.5/NFE=5,p=2.npz')
show_scale('/data/ldm/scale_traj7.5/NFE=10,p=2.npz')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 11
#       8     plt.show()
#      10 #show_scale('/data/ldm/scale7.5/NFE=5,p=2.npz')
# ---> 11 show_scale('/data/ldm/scale_traj7.5/NFE=10,p=2.npz')
#
# Cell In[17], line 5, in show_scale(npz_file)
#       4 def show_scale(npz_file):
# ----> 5     data = np.load(npz_file)
#       6     log_scales = data['optimal_log_scales']
#       7     plt.plot(log_scales.T)
#
# File ~/miniconda3/envs/rbf/lib/python3.11/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# ...

# %%
# !ls /data/ldm/scale7.5 -l
# Out:
# total 20204
# -rw-rw-r-- 1 logpx logpx    450 Apr 16 12:20 'NFE=10,p=2.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:17 'NFE=10,p=2,number=0.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:19 'NFE=10,p=2,number=10.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:19 'NFE=10,p=2,number=11.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:19 'NFE=10,p=2,number=12.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:19 'NFE=10,p=2,number=13.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:19 'NFE=10,p=2,number=14.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:20 'NFE=10,p=2,number=15.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:20 'NFE=10,p=2,number=16.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:20 'NFE=10,p=2,number=17.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:20 'NFE=10,p=2,number=18.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:20 'NFE=10,p=2,number=19.npz'
# -rw-rw-r-- 1 logpx logpx  79118 Apr 16 12:17 'NFE=10,p=2,number=1.npz'
# ...
