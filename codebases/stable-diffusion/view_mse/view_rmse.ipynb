# %%
import numpy as np

# NFE columns that every row corresponds to
nfe = np.array([5, 6, 8, 10, 12, 15, 20])

results = {
    1.5: {
        "DPM‑Solver++"       : np.array([0.070, 0.053, 0.035, 0.026, 0.019, 0.013, 0.008]),
        "UniPC‑bh2"          : np.array([0.058, 0.044, 0.028, 0.019, 0.013, 0.008, 0.004]),
        "DPM‑Solver v3"      : np.array([0.044, 0.035, 0.022, 0.014, 0.009, 0.005, 0.002]),
        "RBF Marginal p=2"   : np.array([0.053, 0.040, 0.026, 0.018, 0.012, 0.007, 0.004]),
        "RBF Marginal p=3"   : np.array([0.051, 0.040, 0.026, 0.017, 0.011, 0.007, 0.003]),
    },

    3.5: {
        "DPM‑Solver++"       : np.array([0.133, 0.116, 0.092, 0.076, 0.063, 0.049, 0.034]),
        "UniPC‑bh2"          : np.array([0.129, 0.114, 0.090, 0.071, 0.057, 0.041, 0.025]),
        "DPM‑Solver v3"      : np.full_like(nfe, np.nan),                     # 값 없음
        "RBF Marginal p=2"   : np.array([0.129, 0.115, 0.091, 0.072, 0.057, 0.041, 0.024]),
        "RBF Marginal p=3"   : np.array([0.131, 0.117, 0.093, 0.073, 0.058, 0.041, 0.025]),
    },

    5.5: {
        "DPM‑Solver++"       : np.array([0.223, 0.202, 0.170, 0.144, 0.124, 0.102, 0.075]),
        "UniPC‑bh2"          : np.array([0.227, 0.207, 0.173, 0.145, 0.123, 0.098, 0.067]),
        "DPM‑Solver v3"      : np.full_like(nfe, np.nan),                     # 값 없음
        "RBF Marginal p=2"   : np.array([0.229, 0.210, 0.177, 0.149, 0.126, 0.099, 0.068]),
        "RBF Marginal p=3"   : np.array([0.228, 0.207, 0.174, 0.147, 0.126, 0.100, 0.070]),
    },

    7.5: {
        "DPM‑Solver++"       : np.array([0.338, 0.308, 0.264, 0.228, 0.201, 0.168, 0.129]),
        "UniPC‑bh2"          : np.array([0.350, 0.321, 0.275, 0.238, 0.206, 0.172, 0.127]),
        "DPM‑Solver v3"      : np.array([0.409, 0.359, 0.289, 0.243, 0.207, 0.170, 0.127]),
        "RBF Marginal p=2"   : np.array([0.335, 0.308, 0.268, 0.233, 0.206, 0.172, 0.129]),
        "RBF Marginal p=3"   : np.array([0.333, 0.303, 0.263, 0.229, 0.201, 0.171, 0.129]),
    },

    9.5: {
        "DPM‑Solver++"       : np.array([0.480, 0.438, 0.375, 0.327, 0.291, 0.247, 0.195]),
        "UniPC‑bh2"          : np.array([0.503, 0.464, 0.401, 0.349, 0.309, 0.261, 0.202]),
        "DPM‑Solver v3"      : np.full_like(nfe, np.nan),                     # 값 없음
        "RBF Marginal p=2"   : np.array([0.460, 0.421, 0.362, 0.322, 0.293, 0.251, 0.199]),
        "RBF Marginal p=3"   : np.array([0.460, 0.418, 0.361, 0.319, 0.288, 0.247, 0.197]),
    },
}
for key1 in results.keys():
    result = results[key1]
    for key2 in result.keys():
        print(key1, key2)
        rmse = np.sqrt(result[key2])
        row = " ".join(f"{x:.3f}" for x in rmse)
        print(f"{row}")
    print()
# Out:
# 1.5 DPM‑Solver++
# 0.265 0.230 0.187 0.161 0.138 0.114 0.089
# 1.5 UniPC‑bh2
# 0.241 0.210 0.167 0.138 0.114 0.089 0.063
# 1.5 DPM‑Solver v3
# 0.210 0.187 0.148 0.118 0.095 0.071 0.045
# 1.5 RBF Marginal p=2
# 0.230 0.200 0.161 0.134 0.110 0.084 0.063
# 1.5 RBF Marginal p=3
# 0.226 0.200 0.161 0.130 0.105 0.084 0.055
#
# 3.5 DPM‑Solver++
# 0.365 0.341 0.303 0.276 0.251 0.221 0.184
# 3.5 UniPC‑bh2
# 0.359 0.338 0.300 0.266 0.239 0.202 0.158
# 3.5 DPM‑Solver v3
# nan nan nan nan nan nan nan
# 3.5 RBF Marginal p=2
# 0.359 0.339 0.302 0.268 0.239 0.202 0.155
# 3.5 RBF Marginal p=3
# 0.362 0.342 0.305 0.270 0.241 0.202 0.158
#
# 5.5 DPM‑Solver++
# 0.472 0.449 0.412 0.379 0.352 0.319 0.274
# 5.5 UniPC‑bh2
# 0.476 0.455 0.416 0.381 0.351 0.313 0.259
# 5.5 DPM‑Solver v3
# nan nan nan nan nan nan nan
# 5.5 RBF Marginal p=2
# 0.479 0.458 0.421 0.386 0.355 0.315 0.261
# 5.5 RBF Marginal p=3
# 0.477 0.455 0.417 0.383 0.355 0.316 0.265
#
# 7.5 DPM‑Solver++
# ...
