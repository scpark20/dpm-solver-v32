# %%
import numpy as np
NFE=5
npz_file = f'/data/score_sde_scale_rbf_marginal_inception/NFE={NFE},p=3.npz'
data = np.load(npz_file)
print(list(data.keys()))

import matplotlib.pyplot as plt
plt.figure(figsize=[5, 3])
plt.title(f"NFE={NFE}")
plt.plot(data['optimal_log_scales'][0].T, label='predictor')
plt.plot(data['optimal_log_scales'][1].T, label='corrector')
plt.grid()
plt.legend()
plt.show()
# Out:
# ['optimal_log_scales', 'loss_grid_list']
