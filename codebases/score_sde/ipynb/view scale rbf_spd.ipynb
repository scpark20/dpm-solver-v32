# %%
import numpy as np
NFE=5
npz_file = f'/data/score_sde_scale_rbf_spd/NFE={NFE},p=3.npz'
data = np.load(npz_file)
print(list(data.keys()))
# Out:
# ['optimal_log_scales', 'pred_losses_list', 'corr_losses_list', 'pred_coeffs_list', 'lag_coeffs_list']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[5, 3])
plt.title(f"NFE={NFE}")
plt.plot(data['optimal_log_scales'].T)
plt.grid()
plt.show()

# %%
log_s = np.linspace(-2.0, 2.0, 100)
plt.figure(figsize=[5, 3])
for i, pred_losses in enumerate(data['pred_losses_list']):
    #plt.title(f"step: {i}")
    plt.plot(log_s, pred_losses)
plt.grid()
plt.show()

# %%
log_s = np.linspace(-2.0, 2.0, 100)
plt.figure(figsize=[5, 3])
for i, pred_losses in enumerate(data['corr_losses_list']):
    #plt.title(f"step: {i}")
    plt.plot(log_s, pred_losses)
plt.grid()
plt.show()
