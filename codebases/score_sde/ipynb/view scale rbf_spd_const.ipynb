# %%
import numpy as np
NFE=5
npz_file = f'/data/score_sde_scale_rbf_spd_const/NFE={NFE},p=3.npz'
data = np.load(npz_file)
print(list(data.keys()))
# Out:
# ['optimal_log_scale', 'losses']

# %%
import matplotlib.pyplot as plt

log_s = np.linspace(0, 3, 100)
plt.figure(figsize=[5, 3])
for NFE in [5, 6, 8, 10, 12, 15, 20]:
    npz_file = f'/data/score_sde_scale_rbf_spd_const/NFE={NFE},p=3.npz'
    data = np.load(npz_file)
    plt.plot(log_s, data['losses'])
    plt.ylim([0.0, 0.02])
    plt.grid()
plt.show()
