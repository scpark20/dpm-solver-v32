# %%
import numpy as np
NFE=10
npz_file = f'/data/score_sde_scale_rbf_plag_ctarget/NFE={NFE},p=3.npz'
#npz_file = f'/data/score_sde_scale_rbf/NFE={NFE},p=3.npz'
data = np.load(npz_file)
print(list(data.keys()))
# Out:
# ['optimal_log_scales', 'pred_losses_list', 'corr_losses_list']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[5, 3])
plt.title(f"NFE={NFE}")
plt.plot(data['optimal_log_scales'].T)
plt.grid()
plt.show()

# %%
log_s = np.linspace(-2.0, 2.0, 100)
plt.figure(figsize=[5, 3])
for i, pred_losses in enumerate(data['corr_losses_list']):
    #plt.title(f"step: {i}")
    plt.plot(log_s, pred_losses)
plt.grid()
plt.show()

# %%
log_s = np.linspace(-2.0, 2.0, 100)
for i, pred_losses in enumerate(data['corr_losses_list']):
    plt.figure(figsize=[5, 3])
    plt.title(f"step: {i}")
    plt.plot(log_s, pred_losses)
    plt.grid()
    plt.show()
