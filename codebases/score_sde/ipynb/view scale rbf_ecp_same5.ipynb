# %%
import numpy as np
NFE=25
npz_file = f'/data/score_sde_scale_rbf_ecp_same5/NFE={NFE},p=5.npz'
data = np.load(npz_file)
print(list(data.keys()))
# Out:
# ['optimal_log_scales', 'loss_line_list']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[5, 3])
plt.title(f"NFE={NFE}")
plt.plot(data['optimal_log_scales'][0].T, label='predictor')
plt.plot(data['optimal_log_scales'][1].T, label='corrector')
plt.grid()
plt.legend()
plt.show()

# %%
log_s = np.linspace(-2.0, 2.0, 100)
rows = len(data['pred_losses_noise_list'])//5
plt.figure(figsize=[18, rows*5])
for i, (noise_losses, data_losses) in enumerate(zip(data['pred_losses_noise_list'], data['corr_losses_noise_list'])):

    plt.subplot(rows+1, 5, i+1)
    plt.title(f"step: {i+1}")
    plt.plot(log_s, data_losses)
    plt.plot(log_s, noise_losses)
    plt.grid()
    #plt.ylim([0, 0.5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 log_s = np.linspace(-2.0, 2.0, 100)
# ----> 2 rows = len(data['pred_losses_noise_list'])//5
#       3 plt.figure(figsize=[18, rows*5])
#       4 for i, (noise_losses, data_losses) in enumerate(zip(data['pred_losses_noise_list'], data['corr_losses_noise_list'])):
#
# File ~/miniconda3/envs/rbf/lib/python3.11/site-packages/numpy/lib/npyio.py:260, in NpzFile.__getitem__(self, key)
#     258         return self.zip.read(key)
#     259 else:
# --> 260     raise KeyError("%s is not a file in the archive" % key)
#
# KeyError: 'pred_losses_noise_list is not a file in the archive'

# %%
log_s = np.linspace(-2.0, 2.0, 100)
rows = len(data['pred_losses_data_list'])//5
plt.figure(figsize=[18, rows*5])
for i, (noise_losses, data_losses) in enumerate(zip(data['pred_losses_data_list'], data['corr_losses_data_list'])):

    plt.subplot(rows+1, 5, i+1)
    plt.title(f"step: {i+1}")
    plt.plot(log_s, data_losses)
    plt.plot(log_s, noise_losses)
    plt.grid()
    #plt.ylim([0, 0.5])
plt.show()
